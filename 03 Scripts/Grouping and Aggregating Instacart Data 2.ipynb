# %% [markdown]
# 1) Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.
#
# 2) In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.
#
# 3) Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.
#
# 4) Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.
#
# 5) The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.
#
# 6) The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”
#
# 7) In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
#
# 8) Ensure your notebook is clean and structured and that your code is well commented.
#
# 9) Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %% [markdown]
# # --------Task--------

# %% [markdown]
# ## Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Creating a path to the .pkl file

# %%
# Path to the project folder
path = r'C:\Users\mmoss\20-12-2021 Instacart Basket Analysis'

# %% [markdown]
# ### Importing ords_prods_merge

# %%
# Importing the 4.8_ords_products_merged_derived
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.7_ords_products_merged_derived.pkl'))

# %% [markdown]
# ### 2. Finding the aggregated mean of order_number column grouped by department_id

# %%
# Finding the average order_number grouped by department for the entire dataframe
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.667853
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### 3. Result of analysis

# %% [markdown]
# The difference between the subset and the entire dataframe is that the subset has the mean number of orders for departments 4,7,13,14,16,17, 19 and 20. It's highest mean comes from the dairy eggs department (mean = 19.46) and the lowest mean comes from the household department (mean = 11.29).
#
# The entire dataframe has means for all departments (1-21) and the department with the highest mean is missing (mean = 22.91) and the lowest mean is the alcohol department (mean = 15.21).

# %% [markdown]
# ### 4. Loyalty Flag

# %%
# Creating the max_order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Testing it
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                     15.0        False         196                  1
# 2                     21.0        False         196                  1
# 3                     29.0        False         196                  1
# 4                     28.0        False         196                  1
# 5                     19.0        False         196                  1
# 6                     20.0        False         196                  1
# 7                     14.0        False         196                  2
# 8                      0.0        False         196                  4
# 9                     30.0        False         196                  1
# 10                     7.0        False         196                  2
# 11                     8.0        False         196                  6
# 12                     7.0        False         196                  1
# 13                     7.0        False         196                  1
# 14                    14.0        False         196                  1
#
#     reordered _merge product_name  aisle_id  department_id  prices  \
# 0           0   both         Soda        77              7     9.0
# 1           1   both         Soda        77              7     9.0
# 2           1   both         Soda        77              7     9.0
# 3           1   both         Soda        77              7     9.0
# 4           1   both         Soda        77              7     9.0
# 5           1   both         Soda        77              7     9.0
# 6           1   both         Soda        77              7     9.0
# 7           1   both         Soda        77              7     9.0
# 8           1   both         Soda        77              7     9.0
# 9           1   both         Soda        77              7     9.0
# 10          0   both         Soda        77              7     9.0
# 11          1   both         Soda        77              7     9.0
# 12          1   both         Soda        77              7     9.0
# 13          1   both         Soda        77              7     9.0
# 14          1   both         Soda        77              7     9.0
#
#       price_range_loc     busiest_day   busiest_day_2 busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 1   Mid-range product  Regularly busy    Slowest days         Fewest orders
# 2   Mid-range product  Regularly busy    Slowest days         Fewest orders
# 3   Mid-range product      Least busy  Regularly busy         Fewest orders
# 4   Mid-range product      Least busy  Regularly busy         Fewest orders
# 5   Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 6   Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 7   Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 8   Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 9   Mid-range product      Least busy  Regularly busy         Fewest orders
# 10  Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 11  Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 12  Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 13  Mid-range product  Regularly busy  Regularly busy         Fewest orders
# 14  Mid-range product  Regularly busy  Regularly busy           Most orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         22
# 11         22
# 12         22
# 13         22
# 14         22

# %% [markdown]
# There's the column!

# %%
# Code for the Loyal Customer
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Code for Regular Customer
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Code for New Customer
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking frequencies of all the customer types
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15874128
# Loyal customer      10282763
# New customer         6242841
# Name: loyalty_flag, dtype: int64

# %%
# Test it out
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# Success!

# %% [markdown]
# ### 5. What customer group pays the higher average price?

# %%
# Finding the average price grouped by loyalty flag for the entire dataframe
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal customer    7.773575
# New customer      7.801206
# Regular customer  7.798262

# %% [markdown]
# New customers appear to pay the most but just by a narrow margin. A couple cents is the difference.

# %% [markdown]
# ### 6.

# %%
# Create the average price paid column by the user
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.average)

# %%
# Testing it
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                     15.0        False         196                  1
# 2                     21.0        False         196                  1
# 3                     29.0        False         196                  1
# 4                     28.0        False         196                  1
# ..                     ...          ...         ...                ...
# 95                     NaN         True         196                  1
# 96                     3.0        False         196                  9
# 97                    22.0        False         196                  3
# 98                    30.0        False         196                  2
# 99                    16.0        False         196                  2
#
#     reordered  ...    price_range_loc     busiest_day   busiest_day_2  \
# 0           0  ...  Mid-range product  Regularly busy  Regularly busy
# 1           1  ...  Mid-range product  Regularly busy    Slowest days
# 2           1  ...  Mid-range product  Regularly busy    Slowest days
# 3           1  ...  Mid-range product      Least busy  Regularly busy
# 4           1  ...  Mid-range product      Least busy  Regularly busy
# ..        ...  ...                ...             ...             ...
# 95          0  ...  Mid-range product  Regularly busy  Regularly busy
# 96          0  ...  Mid-range product  Regularly busy  Regularly busy
# 97          0  ...  Mid-range product      Least busy  Regularly busy
# 98          0  ...  Mid-range product  Regularly busy  Regularly busy
# 99          1  ...  Mid-range product  Regularly busy    Slowest days
#
#     busiest_period_of_day  max_order      loyalty_flag average_price  \
# 0           Fewest orders         10      New customer      6.367797
# 1           Fewest orders         10      New customer      6.367797
# 2           Fewest orders         10      New customer      6.367797
# 3           Fewest orders         10      New customer      6.367797
# 4           Fewest orders         10      New customer      6.367797
# ..                    ...        ...               ...           ...
# 95          Fewest orders          3      New customer     10.006250
# 96          Fewest orders          3      New customer      8.496552
# 97            Most orders          8      New customer      7.396610
# 98          Fewest orders         22  Regular customer      7.387805
# 99          Fewest orders         22  Regular customer      7.387805
#
#    spending_flag median_days_since_last_order         frequency_flag
# 0   High Spender                         20.5  Non-Frequent Customer
# 1   High Spender                         20.5  Non-Frequent Customer
# 2   High Spender                         20.5  Non-Frequent Customer
# 3   High Spender                         20.5  Non-Frequent Customer
# 4   High Spender                         20.5  Non-Frequent Customer
# ..           ...                          ...                    ...
# 95  High Spender                          4.0      Frequent Customer
# 96  High Spender                         16.5       Regular customer
# 97  High Spender                          8.0      Frequent Customer
# 98  High Spender                          7.0      Frequent Customer
# 99  High Spender                          7.0      Frequent Customer
#
# [100 rows x 25 columns]

# %%
# Code for Low Spender
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low Spender'

# %%
# Code for High Spender
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
# Testing it
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                     15.0        False         196                  1
# 2                     21.0        False         196                  1
# 3                     29.0        False         196                  1
# 4                     28.0        False         196                  1
# 5                     19.0        False         196                  1
# 6                     20.0        False         196                  1
# 7                     14.0        False         196                  2
# 8                      0.0        False         196                  4
# 9                     30.0        False         196                  1
# 10                     7.0        False         196                  2
# 11                     8.0        False         196                  6
# 12                     7.0        False         196                  1
# 13                     7.0        False         196                  1
# 14                    14.0        False         196                  1
# 15                     6.0        False         196                  3
# 16                     8.0        False         196                 15
# 17                     6.0        False         196                  1
# 18                     6.0        False         196                  2
# 19                     7.0        False         196                 17
#
#     reordered  ... department_id prices    price_range_loc     busiest_day  \
# 0           0  ...             7    9.0  Mid-range product  Regularly busy
# 1           1  ...             7    9.0  Mid-range product  Regularly busy
# 2           1  ...             7    9.0  Mid-range product  Regularly busy
# 3           1  ...             7    9.0  Mid-range product      Least busy
# 4           1  ...             7    9.0  Mid-range product      Least busy
# 5           1  ...             7    9.0  Mid-range product  Regularly busy
# 6           1  ...             7    9.0  Mid-range product  Regularly busy
# 7           1  ...             7    9.0  Mid-range product  Regularly busy
# 8           1  ...             7    9.0  Mid-range product  Regularly busy
# 9           1  ...             7    9.0  Mid-range product      Least busy
# 10          0  ...             7    9.0  Mid-range product  Regularly busy
# 11          1  ...             7    9.0  Mid-range product  Regularly busy
# 12          1  ...             7    9.0  Mid-range product  Regularly busy
# 13          1  ...             7    9.0  Mid-range product  Regularly busy
# 14          1  ...             7    9.0  Mid-range product  Regularly busy
# 15          0  ...             7    9.0  Mid-range product  Regularly busy
# 16          1  ...             7    9.0  Mid-range product  Regularly busy
# 17          1  ...             7    9.0  Mid-range product      Least busy
# 18          0  ...             7    9.0  Mid-range product  Regularly busy
# 19          0  ...             7    9.0  Mid-range product  Regularly busy
#
#      busiest_day_2 busiest_period_of_day max_order      loyalty_flag  \
# 0   Regularly busy         Fewest orders        10      New customer
# 1     Slowest days         Fewest orders        10      New customer
# 2     Slowest days         Fewest orders        10      New customer
# 3   Regularly busy         Fewest orders        10      New customer
# 4   Regularly busy         Fewest orders        10      New customer
# 5   Regularly busy         Fewest orders        10      New customer
# 6   Regularly busy         Fewest orders        10      New customer
# 7   Regularly busy         Fewest orders        10      New customer
# 8   Regularly busy         Fewest orders        10      New customer
# 9   Regularly busy         Fewest orders        10      New customer
# 10  Regularly busy         Fewest orders        22  Regular customer
# 11  Regularly busy         Fewest orders        22  Regular customer
# 12  Regularly busy         Fewest orders        22  Regular customer
# 13  Regularly busy         Fewest orders        22  Regular customer
# 14  Regularly busy           Most orders        22  Regular customer
# 15  Regularly busy         Fewest orders         9      New customer
# 16  Regularly busy         Fewest orders         9      New customer
# 17  Regularly busy         Fewest orders         9      New customer
# 18    Slowest days           Most orders        33  Regular customer
# 19    Slowest days         Fewest orders        20  Regular customer
#
#    average_price  spending_flag
# 0           14.0   High Spender
# 1           14.0   High Spender
# 2           14.0   High Spender
# 3           14.0   High Spender
# 4           14.0   High Spender
# 5           14.0   High Spender
# 6           14.0   High Spender
# 7           14.0   High Spender
# 8           14.0   High Spender
# 9           14.0   High Spender
# 10           9.0    Low Spender
# 11           9.0    Low Spender
# 12           9.0    Low Spender
# 13           9.0    Low Spender
# 14           9.0    Low Spender
# 15          23.9   High Spender
# 16          23.9   High Spender
# 17          23.9   High Spender
# 18          15.0   High Spender
# 19          24.1   High Spender
#
# [20 rows x 23 columns]

# %%
# Value Counts
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low Spender     32280045
# High Spender      119687
# Name: spending_flag, dtype: int64

# %% [markdown]
# Lots more low spenders than high!

# %%
spendingtest = ords_prods_merge[['average_price', 'spending_flag']]

# %%
#calling it
spendingtest
# Out:
#           average_price spending_flag
# 0              6.367797   Low Spender
# 1              6.367797   Low Spender
# 2              6.367797   Low Spender
# 3              6.367797   Low Spender
# 4              6.367797   Low Spender
# ...                 ...           ...
# 32404854       6.905655   Low Spender
# 32404855       6.905655   Low Spender
# 32404856       7.631579   Low Spender
# 32404857       7.631579   Low Spender
# 32404858       7.684746   Low Spender
#
# [32399732 rows x 2 columns]

# %% [markdown]
# ### 7. Frequent / Non-frequent Customer

# %%
# Create the median_days_since_last_order column by the user
ords_prods_merge['median_days_since_last_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Testing it
ords_prods_merge.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                     15.0        False         196                  1
# 2                     21.0        False         196                  1
# 3                     29.0        False         196                  1
# 4                     28.0        False         196                  1
# 5                     19.0        False         196                  1
# 6                     20.0        False         196                  1
# 7                     14.0        False         196                  2
# 8                      0.0        False         196                  4
# 9                     30.0        False         196                  1
# 10                     7.0        False         196                  2
# 11                     8.0        False         196                  6
# 12                     7.0        False         196                  1
# 13                     7.0        False         196                  1
# 14                    14.0        False         196                  1
# 15                     6.0        False         196                  3
# 16                     8.0        False         196                 15
# 17                     6.0        False         196                  1
# 18                     6.0        False         196                  2
# 19                     7.0        False         196                 17
# 20                     8.0        False         196                 14
# 21                     4.0        False         196                  9
# 22                     3.0        False         196                  1
# 23                     NaN         True         196                  4
# 24                     7.0        False         196                  5
#
#     reordered  ... prices    price_range_loc     busiest_day   busiest_day_2  \
# 0           0  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 1           1  ...    9.0  Mid-range product  Regularly busy    Slowest days
# 2           1  ...    9.0  Mid-range product  Regularly busy    Slowest days
# 3           1  ...    9.0  Mid-range product      Least busy  Regularly busy
# 4           1  ...    9.0  Mid-range product      Least busy  Regularly busy
# 5           1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 6           1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 7           1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 8           1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 9           1  ...    9.0  Mid-range product      Least busy  Regularly busy
# 10          0  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 11          1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 12          1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 13          1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 14          1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 15          0  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 16          1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 17          1  ...    9.0  Mid-range product      Least busy  Regularly busy
# 18          0  ...    9.0  Mid-range product  Regularly busy    Slowest days
# 19          0  ...    9.0  Mid-range product  Regularly busy    Slowest days
# 20          1  ...    9.0  Mid-range product  Regularly busy    Slowest days
# 21          0  ...    9.0  Mid-range product      Least busy  Regularly busy
# 22          1  ...    9.0  Mid-range product      Least busy  Regularly busy
# 23          0  ...    9.0  Mid-range product  Regularly busy  Regularly busy
# 24          1  ...    9.0  Mid-range product  Regularly busy  Regularly busy
#
#     busiest_period_of_day max_order      loyalty_flag average_price  \
# 0           Fewest orders        10      New customer      6.367797
# 1           Fewest orders        10      New customer      6.367797
# 2           Fewest orders        10      New customer      6.367797
# 3           Fewest orders        10      New customer      6.367797
# 4           Fewest orders        10      New customer      6.367797
# 5           Fewest orders        10      New customer      6.367797
# 6           Fewest orders        10      New customer      6.367797
# 7           Fewest orders        10      New customer      6.367797
# 8           Fewest orders        10      New customer      6.367797
# 9           Fewest orders        10      New customer      6.367797
# 10          Fewest orders        22  Regular customer      3.980556
# 11          Fewest orders        22  Regular customer      3.980556
# 12          Fewest orders        22  Regular customer      3.980556
# 13          Fewest orders        22  Regular customer      3.980556
# 14            Most orders        22  Regular customer      3.980556
# 15          Fewest orders         9      New customer      8.372059
# 16          Fewest orders         9      New customer      8.372059
# 17          Fewest orders         9      New customer      8.372059
# 18            Most orders        33  Regular customer      7.012683
# 19          Fewest orders        20  Regular customer      8.137793
# 20          Fewest orders        20  Regular customer      8.137793
# 21          Fewest orders        11  Regular customer      7.444898
# 22          Fewest orders        11  Regular customer      7.444898
# 23          Fewest orders        27  Regular customer      6.356287
# 24            Most orders        27  Regular customer      6.356287
#
#    spending_flag  median_days_since_last_order
# 0   High Spender                          20.5
# 1   High Spender                          20.5
# 2   High Spender                          20.5
# 3   High Spender                          20.5
# 4   High Spender                          20.5
# 5   High Spender                          20.5
# 6   High Spender                          20.5
# 7   High Spender                          20.5
# 8   High Spender                          20.5
# 9   High Spender                          20.5
# 10   Low Spender                          10.0
# 11   Low Spender                          10.0
# 12   Low Spender                          10.0
# 13   Low Spender                          10.0
# 14   Low Spender                          10.0
# 15  High Spender                           6.0
# 16  High Spender                           6.0
# 17  High Spender                           6.0
# 18  High Spender                           7.5
# 19  High Spender                           6.0
# 20  High Spender                           6.0
# 21  High Spender                          10.0
# 22  High Spender                          10.0
# 23  High Spender                           8.0
# 24  High Spender                           8.0
#
# [25 rows x 24 columns]

# %%
# Code for Non-Frequent Customer
ords_prods_merge.loc[ords_prods_merge['median_days_since_last_order'] > 20, 'frequency_flag'] = 'Non-Frequent Customer'

# %%
# Code for Regular Customer
ords_prods_merge.loc[(ords_prods_merge['median_days_since_last_order'] > 10) & (ords_prods_merge['median_days_since_last_order'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
# Code for Frequent Customer
ords_prods_merge.loc[ords_prods_merge['median_days_since_last_order'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
# Testing it
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 1                     15.0        False         196                  1
# 2                     21.0        False         196                  1
# 3                     29.0        False         196                  1
# 4                     28.0        False         196                  1
# ..                     ...          ...         ...                ...
# 95                     NaN         True         196                  1
# 96                     3.0        False         196                  9
# 97                    22.0        False         196                  3
# 98                    30.0        False         196                  2
# 99                    16.0        False         196                  2
#
#     reordered  ...    price_range_loc     busiest_day   busiest_day_2  \
# 0           0  ...  Mid-range product  Regularly busy  Regularly busy
# 1           1  ...  Mid-range product  Regularly busy    Slowest days
# 2           1  ...  Mid-range product  Regularly busy    Slowest days
# 3           1  ...  Mid-range product      Least busy  Regularly busy
# 4           1  ...  Mid-range product      Least busy  Regularly busy
# ..        ...  ...                ...             ...             ...
# 95          0  ...  Mid-range product  Regularly busy  Regularly busy
# 96          0  ...  Mid-range product  Regularly busy  Regularly busy
# 97          0  ...  Mid-range product      Least busy  Regularly busy
# 98          0  ...  Mid-range product  Regularly busy  Regularly busy
# 99          1  ...  Mid-range product  Regularly busy    Slowest days
#
#     busiest_period_of_day  max_order      loyalty_flag average_price  \
# 0           Fewest orders         10      New customer      6.367797
# 1           Fewest orders         10      New customer      6.367797
# 2           Fewest orders         10      New customer      6.367797
# 3           Fewest orders         10      New customer      6.367797
# 4           Fewest orders         10      New customer      6.367797
# ..                    ...        ...               ...           ...
# 95          Fewest orders          3      New customer     10.006250
# 96          Fewest orders          3      New customer      8.496552
# 97            Most orders          8      New customer      7.396610
# 98          Fewest orders         22  Regular customer      7.387805
# 99          Fewest orders         22  Regular customer      7.387805
#
#    spending_flag median_days_since_last_order         frequency_flag
# 0   High Spender                         20.5  Non-Frequent Customer
# 1   High Spender                         20.5  Non-Frequent Customer
# 2   High Spender                         20.5  Non-Frequent Customer
# 3   High Spender                         20.5  Non-Frequent Customer
# 4   High Spender                         20.5  Non-Frequent Customer
# ..           ...                          ...                    ...
# 95  High Spender                          4.0      Frequent Customer
# 96  High Spender                         16.5       Regular customer
# 97  High Spender                          8.0      Frequent Customer
# 98  High Spender                          7.0      Frequent Customer
# 99  High Spender                          7.0      Frequent Customer
#
# [100 rows x 25 columns]

# %% [markdown]
# Success!

# %% [markdown]
# ### 9. Exporting the .pkl file

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.8_ords_products_merged_derived_grouped.pkl'))
